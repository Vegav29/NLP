# %%
import nltk
from nltk.corpus import stopwords
import string
import pandas as pd
import numpy as np
import warnings
import sys
import re
warnings.filterwarnings("ignore")
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
import spacy
from nltk.util import ngrams
from nltk.lm import Vocabulary
from nltk.lm.preprocessing import pad_both_ends

# %%
file_path = '/content/cnbc_headlines.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#                                            Headlines  \
# 0  Jim Cramer: A better way to invest in the Covi...
# 1     Cramer's lightning round: I would own Teradyne
# 2                                                NaN
# 3  Cramer's week ahead: Big week for earnings, ev...
# 4  IQ Capital CEO Keith Bliss says tech and healt...
#
#                              Time  \
# 0   7:51  PM ET Fri, 17 July 2020
# 1   7:33  PM ET Fri, 17 July 2020
# 2                             NaN
# 3   7:25  PM ET Fri, 17 July 2020
# 4   4:24  PM ET Fri, 17 July 2020
#
#                                          Description
# 0  "Mad Money" host Jim Cramer recommended buying...
# 1  "Mad Money" host Jim Cramer rings the lightnin...
# 2                                                NaN
# 3  "We'll pay more for the earnings of the non-Co...
# 4  Keith Bliss, IQ Capital CEO, joins "Closing Be...

# %%
def clean_text(text):
    if isinstance(text, str):
        text = re.sub(r'<.*?>', '', text)
        text = text.lower()
        text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
        text = re.sub(r'\s+', ' ', text).strip()

    return text

# %%
df['cleaned_headline'] = df['Headlines'].apply(clean_text)

# %%
df.head()
# Out:
#                                            Headlines  \
# 0  Jim Cramer: A better way to invest in the Covi...
# 1     Cramer's lightning round: I would own Teradyne
# 2                                                NaN
# 3  Cramer's week ahead: Big week for earnings, ev...
# 4  IQ Capital CEO Keith Bliss says tech and healt...
#
#                              Time  \
# 0   7:51  PM ET Fri, 17 July 2020
# 1   7:33  PM ET Fri, 17 July 2020
# 2                             NaN
# 3   7:25  PM ET Fri, 17 July 2020
# 4   4:24  PM ET Fri, 17 July 2020
#
#                                          Description  \
# 0  "Mad Money" host Jim Cramer recommended buying...
# 1  "Mad Money" host Jim Cramer rings the lightnin...
# 2                                                NaN
# 3  "We'll pay more for the earnings of the non-Co...
# 4  Keith Bliss, IQ Capital CEO, joins "Closing Be...
#
#                                     cleaned_headline
# 0  jim cramer a better way to invest in the covid...
# 1       cramers lightning round i would own teradyne
# 2                                                NaN
# 3  cramers week ahead big week for earnings even ...
# 4  iq capital ceo keith bliss says tech and healt...

# %%
df.shape
# Out:
# (3080, 4)

# %%
df.isnull().sum()
# Out:
# Headlines           280
# Time                280
# Description         280
# cleaned_headline    280
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (2800, 4)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#df.drop_duplicates(inplace=True)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['tokenized_headlines'] = df['cleaned_headline'].apply(lambda x: word_tokenize(x))

# %%
df[['Headlines', 'tokenized_headlines']].head()
# Out:
#                                            Headlines  \
# 0  Jim Cramer: A better way to invest in the Covi...
# 1     Cramer's lightning round: I would own Teradyne
# 3  Cramer's week ahead: Big week for earnings, ev...
# 4  IQ Capital CEO Keith Bliss says tech and healt...
# 5  Wall Street delivered the 'kind of pullback I'...
#
#                                  tokenized_headlines
# 0  [jim, cramer, a, better, way, to, invest, in, ...
# 1  [cramers, lightning, round, i, would, own, ter...
# 3  [cramers, week, ahead, big, week, for, earning...
# 4  [iq, capital, ceo, keith, bliss, says, tech, a...
# 5  [wall, street, delivered, the, kind, of, pullb...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def remove_stop_words(tokens):
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
    return filtered_tokens

# %%
df['cleaned_tokens'] = df['tokenized_headlines'].apply(remove_stop_words)
df[['tokenized_headlines', 'cleaned_tokens']].head()
# Out:
#                                  tokenized_headlines  \
# 0  [jim, cramer, a, better, way, to, invest, in, ...
# 1  [cramers, lightning, round, i, would, own, ter...
# 3  [cramers, week, ahead, big, week, for, earning...
# 4  [iq, capital, ceo, keith, bliss, says, tech, a...
# 5  [wall, street, delivered, the, kind, of, pullb...
#
#                                       cleaned_tokens
# 0  [jim, cramer, better, way, invest, covid19, va...
# 1       [cramers, lightning, round, would, teradyne]
# 3  [cramers, week, ahead, big, week, earnings, ev...
# 4  [iq, capital, ceo, keith, bliss, says, tech, h...
# 5  [wall, street, delivered, kind, pullback, ive,...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def perform_lemmatization(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return lemmatized_tokens

def perform_stemming(tokens):
    stemmer = PorterStemmer()
    stemmed_tokens = [stemmer.stem(word) for word in tokens]
    return stemmed_tokens

# %%
df['lemmatized_tokens'] = df['cleaned_tokens'].apply(perform_lemmatization)
df['stemmed_tokens'] = df['cleaned_tokens'].apply(perform_stemming)

# %%
df[['cleaned_tokens', 'lemmatized_tokens', 'stemmed_tokens']]
# Out:
#                                          cleaned_tokens  \
# 0     [jim, cramer, better, way, invest, covid19, va...
# 1          [cramers, lightning, round, would, teradyne]
# 3     [cramers, week, ahead, big, week, earnings, ev...
# 4     [iq, capital, ceo, keith, bliss, says, tech, h...
# 5     [wall, street, delivered, kind, pullback, ive,...
# ...                                                 ...
# 3075                  [markets, lack, christmas, cheer]
# 3076  [cramer, remix, biggest, mistake, make, taxes,...
# 3077  [cramer, says, owning, many, stocks, little, c...
# 3078  [cramer, helped, investors, 2010, flash, crash...
# 3079  [cramer, never, buy, stock, youll, almost, def...
#
#                                       lemmatized_tokens  \
# 0     [jim, cramer, better, way, invest, covid19, va...
# 1          [cramers, lightning, round, would, teradyne]
# 3     [cramers, week, ahead, big, week, earnings, ev...
# 4     [iq, capital, ceo, keith, bliss, say, tech, he...
# 5     [wall, street, delivered, kind, pullback, ive,...
# ...                                                 ...
# 3075                   [market, lack, christmas, cheer]
# 3076  [cramer, remix, biggest, mistake, make, tax, s...
# 3077  [cramer, say, owning, many, stock, little, cas...
# 3078  [cramer, helped, investor, 2010, flash, crash,...
# 3079  [cramer, never, buy, stock, youll, almost, def...
#
#                                          stemmed_tokens
# 0     [jim, cramer, better, way, invest, covid19, va...
# 1               [cramer, lightn, round, would, teradyn]
# 3     [cramer, week, ahead, big, week, earn, even, b...
# 4     [iq, capit, ceo, keith, bliss, say, tech, heal...
# 5     [wall, street, deliv, kind, pullback, ive, wai...
# ...                                                 ...
# 3075                    [market, lack, christma, cheer]
# 3076  [cramer, remix, biggest, mistak, make, tax, st...
# 3077  [cramer, say, own, mani, stock, littl, cash, s...
# 3078  [cramer, help, investor, 2010, flash, crash, f...
# 3079  [cramer, never, buy, stock, youll, almost, def...
#
# [2800 rows x 3 columns]

# %%
df
# Out:
#                                               Headlines  \
# 0     Jim Cramer: A better way to invest in the Covi...
# 1        Cramer's lightning round: I would own Teradyne
# 3     Cramer's week ahead: Big week for earnings, ev...
# 4     IQ Capital CEO Keith Bliss says tech and healt...
# 5     Wall Street delivered the 'kind of pullback I'...
# ...                                                 ...
# 3075                       Markets lack Christmas cheer
# 3076  Cramer Remix: The biggest mistake you can make...
# 3077  Cramer says owning too many stocks and too lit...
# 3078  Cramer: I helped investors through the 2010 fl...
# 3079  Cramer: Never buy a stock all at once — you'll...
#
#                                 Time  \
# 0      7:51  PM ET Fri, 17 July 2020
# 1      7:33  PM ET Fri, 17 July 2020
# 3      7:25  PM ET Fri, 17 July 2020
# 4      4:24  PM ET Fri, 17 July 2020
# 5      7:36  PM ET Thu, 16 July 2020
# ...                              ...
# 3075   10:15  AM ET Tue, 26 Dec 2017
# 3076  11:12  AM ET Thu, 20 Sept 2018
# 3077    7:07  PM ET Fri, 22 Dec 2017
# 3078    7:07  PM ET Fri, 22 Dec 2017
# 3079    6:52  PM ET Fri, 22 Dec 2017
#
#                                             Description  \
# 0     "Mad Money" host Jim Cramer recommended buying...
# 1     "Mad Money" host Jim Cramer rings the lightnin...
# 3     "We'll pay more for the earnings of the non-Co...
# 4     Keith Bliss, IQ Capital CEO, joins "Closing Be...
# 5     "Look for the stocks of high-quality companies...
# ...                                                 ...
# 3075  According to Kensho, here's how markets have f...
# 3076  Jim Cramer revealed his top rule when it comes...
# 3077  Jim Cramer broke down why owning fewer stocks ...
# 3078  Jim Cramer built on his "nobody ever made a di...
# 3079  Jim Cramer doubled down on his key investing r...
#
#                                        cleaned_headline  \
# 0     jim cramer a better way to invest in the covid...
# 1          cramers lightning round i would own teradyne
# 3     cramers week ahead big week for earnings even ...
# 4     iq capital ceo keith bliss says tech and healt...
# 5     wall street delivered the kind of pullback ive...
# ...                                                 ...
# 3075                       markets lack christmas cheer
# 3076  cramer remix the biggest mistake you can make ...
# 3077  cramer says owning too many stocks and too lit...
# 3078  cramer i helped investors through the 2010 fla...
# 3079  cramer never buy a stock all at once youll alm...
#
#                                     tokenized_headlines  \
# 0     [jim, cramer, a, better, way, to, invest, in, ...
# 1     [cramers, lightning, round, i, would, own, ter...
# 3     [cramers, week, ahead, big, week, for, earning...
# 4     [iq, capital, ceo, keith, bliss, says, tech, a...
# 5     [wall, street, delivered, the, kind, of, pullb...
# ...                                                 ...
# 3075                  [markets, lack, christmas, cheer]
# 3076  [cramer, remix, the, biggest, mistake, you, ca...
# 3077  [cramer, says, owning, too, many, stocks, and,...
# 3078  [cramer, i, helped, investors, through, the, 2...
# 3079  [cramer, never, buy, a, stock, all, at, once, ...
#
#                                          cleaned_tokens  \
# 0     [jim, cramer, better, way, invest, covid19, va...
# 1          [cramers, lightning, round, would, teradyne]
# 3     [cramers, week, ahead, big, week, earnings, ev...
# 4     [iq, capital, ceo, keith, bliss, says, tech, h...
# 5     [wall, street, delivered, kind, pullback, ive,...
# ...                                                 ...
# 3075                  [markets, lack, christmas, cheer]
# 3076  [cramer, remix, biggest, mistake, make, taxes,...
# 3077  [cramer, says, owning, many, stocks, little, c...
# 3078  [cramer, helped, investors, 2010, flash, crash...
# 3079  [cramer, never, buy, stock, youll, almost, def...
#
#                                       lemmatized_tokens  \
# 0     [jim, cramer, better, way, invest, covid19, va...
# 1          [cramers, lightning, round, would, teradyne]
# 3     [cramers, week, ahead, big, week, earnings, ev...
# 4     [iq, capital, ceo, keith, bliss, say, tech, he...
# 5     [wall, street, delivered, kind, pullback, ive,...
# ...                                                 ...
# 3075                   [market, lack, christmas, cheer]
# 3076  [cramer, remix, biggest, mistake, make, tax, s...
# 3077  [cramer, say, owning, many, stock, little, cas...
# 3078  [cramer, helped, investor, 2010, flash, crash,...
# 3079  [cramer, never, buy, stock, youll, almost, def...
#
#                                          stemmed_tokens
# 0     [jim, cramer, better, way, invest, covid19, va...
# 1               [cramer, lightn, round, would, teradyn]
# 3     [cramer, week, ahead, big, week, earn, even, b...
# 4     [iq, capit, ceo, keith, bliss, say, tech, heal...
# 5     [wall, street, deliv, kind, pullback, ive, wai...
# ...                                                 ...
# 3075                    [market, lack, christma, cheer]
# 3076  [cramer, remix, biggest, mistak, make, tax, st...
# 3077  [cramer, say, own, mani, stock, littl, cash, s...
# 3078  [cramer, help, investor, 2010, flash, crash, f...
# 3079  [cramer, never, buy, stock, youll, almost, def...
#
# [2800 rows x 8 columns]

# %%
nlp = spacy.load("en_core_web_sm")
def label_entities(text):
    doc = nlp(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# %%
df['entities'] = df['cleaned_headline'].apply(label_entities)

# %%
df[['cleaned_headline', 'entities']]
# Out:
#                                        cleaned_headline  \
# 0     jim cramer a better way to invest in the covid...
# 1          cramers lightning round i would own teradyne
# 3     cramers week ahead big week for earnings even ...
# 4     iq capital ceo keith bliss says tech and healt...
# 5     wall street delivered the kind of pullback ive...
# ...                                                 ...
# 3075                       markets lack christmas cheer
# 3076  cramer remix the biggest mistake you can make ...
# 3077  cramer says owning too many stocks and too lit...
# 3078  cramer i helped investors through the 2010 fla...
# 3079  cramer never buy a stock all at once youll alm...
#
#                                        entities
# 0     [(jim cramer, PERSON), (covid19, PERSON)]
# 1                                            []
# 3       [(big week, DATE), (bigger week, DATE)]
# 4                           [(healthcare, ORG)]
# 5                        [(jim cramer, PERSON)]
# ...                                         ...
# 3075                        [(christmas, DATE)]
# 3076                                         []
# 3077                                         []
# 3078            [(2010, DATE), (one, CARDINAL)]
# 3079                                         []
#
# [2800 rows x 2 columns]

# %%
""" Load the small English model with basic NER
nlp = spacy.load("en_core_web_sm")

# Load the medium-sized English model with basic NER and word vectors
nlp = spacy.load("en_core_web_md")

# Load the large English model with basic NER and word vectors
nlp = spacy.load("en_core_web_lg")

# Load a multilingual model (e.g., Spanish)
nlp = spacy.load("es_core_news_sm")

# Load a domain-specific model (e.g., medical)
nlp = spacy.load("en_core_med7_lg")"""
# Out:
# ' Load the small English model with basic NER\nnlp = spacy.load("en_core_web_sm")\n\n# Load the medium-sized English model with basic NER and word vectors\nnlp = spacy.load("en_core_web_md")\n\n# Load the large English model with basic NER and word vectors\nnlp = spacy.load("en_core_web_lg")\n\n# Load a multilingual model (e.g., Spanish)\nnlp = spacy.load("es_core_news_sm")\n\n# Load a domain-specific model (e.g., medical)\nnlp = spacy.load("en_core_med7_lg")'

# %%
def pos_tagging(tokens):
    pos_tags = nltk.pos_tag(tokens)
    return pos_tags

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
df['pos_tags'] = df['tokenized_headlines'].apply(pos_tagging)

# %%
df[['tokenized_headlines', 'pos_tags']].head()
# Out:
#                                  tokenized_headlines  \
# 0  [jim, cramer, a, better, way, to, invest, in, ...
# 1  [cramers, lightning, round, i, would, own, ter...
# 3  [cramers, week, ahead, big, week, for, earning...
# 4  [iq, capital, ceo, keith, bliss, says, tech, a...
# 5  [wall, street, delivered, the, kind, of, pullb...
#
#                                             pos_tags
# 0  [(jim, NN), (cramer, VBZ), (a, DT), (better, J...
# 1  [(cramers, NNS), (lightning, VBG), (round, NN)...
# 3  [(cramers, NNS), (week, NN), (ahead, RB), (big...
# 4  [(iq, JJ), (capital, NN), (ceo, NN), (keith, N...
# 5  [(wall, JJ), (street, NN), (delivered, VBD), (...

# %%
def pos_tagging(tokens):
    text = ' '.join(tokens)
    doc = nlp(text)
    tagged_text = [(token.text, token.pos_) for token in doc]
    return tagged_text

df['pos_tags_1'] = df['tokenized_headlines'].apply(pos_tagging)
df[['tokenized_headlines', 'pos_tags_1']].head()
# Out:
#                                  tokenized_headlines  \
# 0  [jim, cramer, a, better, way, to, invest, in, ...
# 1  [cramers, lightning, round, i, would, own, ter...
# 3  [cramers, week, ahead, big, week, for, earning...
# 4  [iq, capital, ceo, keith, bliss, says, tech, a...
# 5  [wall, street, delivered, the, kind, of, pullb...
#
#                                           pos_tags_1
# 0  [(jim, PROPN), (cramer, PROPN), (a, DET), (bet...
# 1  [(cramers, NOUN), (lightning, NOUN), (round, A...
# 3  [(cramers, NOUN), (week, VERB), (ahead, ADV), ...
# 4  [(iq, PROPN), (capital, PROPN), (ceo, PROPN), ...
# 5  [(wall, PROPN), (street, PROPN), (delivered, V...

# %%
def pos_tagging(text):
    tokens = nltk.word_tokenize(text)
    text = ' '.join(tokens)
    doc = nlp(text)
    tagged_text = [(token.text, token.pos_) for token in doc]
    return tagged_text

df['pos_tags_2'] = df['Headlines'].apply(pos_tagging)
df[['Headlines', 'pos_tags_2']].head()
# Out:
#                                            Headlines  \
# 0  Jim Cramer: A better way to invest in the Covi...
# 1     Cramer's lightning round: I would own Teradyne
# 3  Cramer's week ahead: Big week for earnings, ev...
# 4  IQ Capital CEO Keith Bliss says tech and healt...
# 5  Wall Street delivered the 'kind of pullback I'...
#
#                                           pos_tags_2
# 0  [(Jim, PROPN), (Cramer, PROPN), (:, PUNCT), (A...
# 1  [(Cramer, PROPN), ('s, PART), (lightning, NOUN...
# 3  [(Cramer, PROPN), ('s, PART), (week, NOUN), (a...
# 4  [(IQ, PROPN), (Capital, PROPN), (CEO, PROPN), ...
# 5  [(Wall, PROPN), (Street, PROPN), (delivered, V...

# %%
df
# Out:
#                                               Headlines  \
# 0     Jim Cramer: A better way to invest in the Covi...
# 1        Cramer's lightning round: I would own Teradyne
# 3     Cramer's week ahead: Big week for earnings, ev...
# 4     IQ Capital CEO Keith Bliss says tech and healt...
# 5     Wall Street delivered the 'kind of pullback I'...
# ...                                                 ...
# 3075                       Markets lack Christmas cheer
# 3076  Cramer Remix: The biggest mistake you can make...
# 3077  Cramer says owning too many stocks and too lit...
# 3078  Cramer: I helped investors through the 2010 fl...
# 3079  Cramer: Never buy a stock all at once — you'll...
#
#                                 Time  \
# 0      7:51  PM ET Fri, 17 July 2020
# 1      7:33  PM ET Fri, 17 July 2020
# 3      7:25  PM ET Fri, 17 July 2020
# 4      4:24  PM ET Fri, 17 July 2020
# 5      7:36  PM ET Thu, 16 July 2020
# ...                              ...
# 3075   10:15  AM ET Tue, 26 Dec 2017
# 3076  11:12  AM ET Thu, 20 Sept 2018
# 3077    7:07  PM ET Fri, 22 Dec 2017
# 3078    7:07  PM ET Fri, 22 Dec 2017
# 3079    6:52  PM ET Fri, 22 Dec 2017
#
#                                             Description  \
# 0     "Mad Money" host Jim Cramer recommended buying...
# 1     "Mad Money" host Jim Cramer rings the lightnin...
# 3     "We'll pay more for the earnings of the non-Co...
# 4     Keith Bliss, IQ Capital CEO, joins "Closing Be...
# 5     "Look for the stocks of high-quality companies...
# ...                                                 ...
# 3075  According to Kensho, here's how markets have f...
# 3076  Jim Cramer revealed his top rule when it comes...
# 3077  Jim Cramer broke down why owning fewer stocks ...
# 3078  Jim Cramer built on his "nobody ever made a di...
# 3079  Jim Cramer doubled down on his key investing r...
#
#                                        cleaned_headline  \
# 0     jim cramer a better way to invest in the covid...
# 1          cramers lightning round i would own teradyne
# 3     cramers week ahead big week for earnings even ...
# 4     iq capital ceo keith bliss says tech and healt...
# 5     wall street delivered the kind of pullback ive...
# ...                                                 ...
# 3075                       markets lack christmas cheer
# 3076  cramer remix the biggest mistake you can make ...
# 3077  cramer says owning too many stocks and too lit...
# 3078  cramer i helped investors through the 2010 fla...
# 3079  cramer never buy a stock all at once youll alm...
#
#                                     tokenized_headlines  \
# 0     [jim, cramer, a, better, way, to, invest, in, ...
# 1     [cramers, lightning, round, i, would, own, ter...
# 3     [cramers, week, ahead, big, week, for, earning...
# 4     [iq, capital, ceo, keith, bliss, says, tech, a...
# 5     [wall, street, delivered, the, kind, of, pullb...
# ...                                                 ...
# 3075                  [markets, lack, christmas, cheer]
# 3076  [cramer, remix, the, biggest, mistake, you, ca...
# 3077  [cramer, says, owning, too, many, stocks, and,...
# 3078  [cramer, i, helped, investors, through, the, 2...
# 3079  [cramer, never, buy, a, stock, all, at, once, ...
#
#                                          cleaned_tokens  \
# 0     [jim, cramer, better, way, invest, covid19, va...
# 1          [cramers, lightning, round, would, teradyne]
# 3     [cramers, week, ahead, big, week, earnings, ev...
# 4     [iq, capital, ceo, keith, bliss, says, tech, h...
# 5     [wall, street, delivered, kind, pullback, ive,...
# ...                                                 ...
# 3075                  [markets, lack, christmas, cheer]
# 3076  [cramer, remix, biggest, mistake, make, taxes,...
# 3077  [cramer, says, owning, many, stocks, little, c...
# 3078  [cramer, helped, investors, 2010, flash, crash...
# 3079  [cramer, never, buy, stock, youll, almost, def...
#
#                                       lemmatized_tokens  \
# 0     [jim, cramer, better, way, invest, covid19, va...
# 1          [cramers, lightning, round, would, teradyne]
# 3     [cramers, week, ahead, big, week, earnings, ev...
# 4     [iq, capital, ceo, keith, bliss, say, tech, he...
# 5     [wall, street, delivered, kind, pullback, ive,...
# ...                                                 ...
# 3075                   [market, lack, christmas, cheer]
# 3076  [cramer, remix, biggest, mistake, make, tax, s...
# 3077  [cramer, say, owning, many, stock, little, cas...
# 3078  [cramer, helped, investor, 2010, flash, crash,...
# 3079  [cramer, never, buy, stock, youll, almost, def...
#
#                                          stemmed_tokens  \
# 0     [jim, cramer, better, way, invest, covid19, va...
# 1               [cramer, lightn, round, would, teradyn]
# 3     [cramer, week, ahead, big, week, earn, even, b...
# 4     [iq, capit, ceo, keith, bliss, say, tech, heal...
# 5     [wall, street, deliv, kind, pullback, ive, wai...
# ...                                                 ...
# 3075                    [market, lack, christma, cheer]
# 3076  [cramer, remix, biggest, mistak, make, tax, st...
# 3077  [cramer, say, own, mani, stock, littl, cash, s...
# 3078  [cramer, help, investor, 2010, flash, crash, f...
# 3079  [cramer, never, buy, stock, youll, almost, def...
#
#                                        entities  \
# 0     [(jim cramer, PERSON), (covid19, PERSON)]
# 1                                            []
# 3       [(big week, DATE), (bigger week, DATE)]
# 4                           [(healthcare, ORG)]
# 5                        [(jim cramer, PERSON)]
# ...                                         ...
# 3075                        [(christmas, DATE)]
# 3076                                         []
# 3077                                         []
# 3078            [(2010, DATE), (one, CARDINAL)]
# 3079                                         []
#
#                                                pos_tags  \
# 0     [(jim, NN), (cramer, VBZ), (a, DT), (better, J...
# 1     [(cramers, NNS), (lightning, VBG), (round, NN)...
# 3     [(cramers, NNS), (week, NN), (ahead, RB), (big...
# 4     [(iq, JJ), (capital, NN), (ceo, NN), (keith, N...
# 5     [(wall, JJ), (street, NN), (delivered, VBD), (...
# ...                                                 ...
# 3075  [(markets, NNS), (lack, VBP), (christmas, NNS)...
# 3076  [(cramer, NN), (remix, VBZ), (the, DT), (bigge...
# 3077  [(cramer, NN), (says, VBZ), (owning, VBG), (to...
# 3078  [(cramer, NN), (i, NN), (helped, VBD), (invest...
# 3079  [(cramer, NN), (never, RB), (buy, VB), (a, DT)...
#
#                                              pos_tags_1  \
# 0     [(jim, PROPN), (cramer, PROPN), (a, DET), (bet...
# 1     [(cramers, NOUN), (lightning, NOUN), (round, A...
# 3     [(cramers, NOUN), (week, VERB), (ahead, ADV), ...
# 4     [(iq, PROPN), (capital, PROPN), (ceo, PROPN), ...
# 5     [(wall, PROPN), (street, PROPN), (delivered, V...
# ...                                                 ...
# 3075  [(markets, NOUN), (lack, VERB), (christmas, PR...
# 3076  [(cramer, PROPN), (remix, VERB), (the, DET), (...
# 3077  [(cramer, PROPN), (says, VERB), (owning, VERB)...
# 3078  [(cramer, PROPN), (i, PRON), (helped, VERB), (...
# 3079  [(cramer, PROPN), (never, ADV), (buy, VERB), (...
#
#                                              pos_tags_2
# 0     [(Jim, PROPN), (Cramer, PROPN), (:, PUNCT), (A...
# 1     [(Cramer, PROPN), ('s, PART), (lightning, NOUN...
# 3     [(Cramer, PROPN), ('s, PART), (week, NOUN), (a...
# 4     [(IQ, PROPN), (Capital, PROPN), (CEO, PROPN), ...
# 5     [(Wall, PROPN), (Street, PROPN), (delivered, V...
# ...                                                 ...
# 3075  [(Markets, NOUN), (lack, VERB), (Christmas, PR...
# 3076  [(Cramer, PROPN), (Remix, PROPN), (:, PUNCT), ...
# 3077  [(Cramer, PROPN), (says, VERB), (owning, VERB)...
# 3078  [(Cramer, NOUN), (:, PUNCT), (I, PRON), (helpe...
# 3079  [(Cramer, NOUN), (:, PUNCT), (Never, ADV), (bu...
#
# [2800 rows x 12 columns]

# %%
def generate_word_ngrams(tokens, n):
    n_grams = list(ngrams(tokens, n))
    return [' '.join(gram) for gram in n_grams]

# %%
n=2
df['word_ngrams'] = df['cleaned_tokens'].apply(lambda x: generate_word_ngrams(x, n))

# %%
df[['cleaned_tokens', 'word_ngrams']].head()
# Out:
#                                       cleaned_tokens  \
# 0  [jim, cramer, better, way, invest, covid19, va...
# 1       [cramers, lightning, round, would, teradyne]
# 3  [cramers, week, ahead, big, week, earnings, ev...
# 4  [iq, capital, ceo, keith, bliss, says, tech, h...
# 5  [wall, street, delivered, kind, pullback, ive,...
#
#                                          word_ngrams
# 0  [jim cramer, cramer better, better way, way in...
# 1  [cramers lightning, lightning round, round wou...
# 3  [cramers week, week ahead, ahead big, big week...
# 4  [iq capital, capital ceo, ceo keith, keith bli...
# 5  [wall street, street delivered, delivered kind...

# %%
word_ngrams_data = df['word_ngrams'].tolist()

# %%
from nltk.lm import MLE
from nltk.util import ngrams
from nltk.lm.preprocessing import pad_both_ends

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import math

# %%
corpus = [' '.join(tokens) for tokens in df['cleaned_tokens']]
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corpus)

vocabulary = vectorizer.get_feature_names_out()
word_counts = X.toarray().sum(axis=0)
total_words = word_counts.sum()

perplexity = 1.0
for word, count in zip(vocabulary, word_counts):
    word_probability = count / total_words
    perplexity *= math.pow(1.0 / word_probability, word_probability)

perplexity = pow(perplexity, 1 / total_words)

perplexity
# Out:
# 1.0002795460449323

# %%
from collections import Counter

# Assuming 'word_ngrams' is your word n-grams column
bigram_counts = Counter(bigram for bigram_list in df['word_ngrams'] for bigram in bigram_list)

# %%
bigram_counts
# Out:
# Counter({'jim cramer': 480,
#          'cramer better': 1,
#          'better way': 2,
#          'way invest': 1,
#          'invest covid19': 1,
#          'covid19 vaccine': 1,
#          'vaccine gold': 1,
#          'gold rush': 1,
#          'cramers lightning': 474,
#          'lightning round': 474,
#          'round would': 6,
#          'would teradyne': 1,
#          'cramers week': 38,
#          'week ahead': 41,
#          'ahead big': 2,
#          'big week': 1,
#          'week earnings': 4,
#          'earnings even': 1,
#          'even bigger': 1,
#          'bigger week': 1,
#          'week vaccines': 1,
#          'iq capital': 1,
#          'capital ceo': 1,
#          'ceo keith': 1,
#          'keith bliss': 1,
#          'bliss says': 1,
#          'says tech': 4,
#          'tech healthcare': 1,
#          'healthcare rally': 1,
#          'wall street': 46,
#          'street delivered': 1,
#          'delivered kind': 1,
#          'kind pullback': 1,
#          'pullback ive': 1,
#          'ive waiting': 1,
#          'waiting jim': 1,
#          'cramer says': 217,
#          'would stay': 1,
#          'stay long': 1,
#          'long wex': 1,
#          'acorns ceo': 1,
#          'ceo parents': 1,
#          'parents turn': 1,
#          'turn 5': 1,
#          '5 five': 1,
#          'five figures': 1,
#          'figures kids': 1,
#          'kids power': 1,
#          'power compounding': 1,
#          'dividend cuts': 2,
#          'cuts may': 2,
#          'may mean': 2,
#          'mean rethinking': 1,
#          'rethinking retirement': 1,
#          'retirement income': 1,
#          'income strategy': 1,
#          'stockx authenticated': 1,
#          'authenticated 1': 1,
#          '1 million': 1,
#          'million jordan': 1,
#          'jordan sneakers': 1,
#          'sneakers year': 1,
#          'year ceo': 1,
#          'ceo says': 97,
#          'biohaven pharmaceuticals': 1,
#          'pharmaceuticals lands': 1,
#          'lands khloe': 1,
#          'khloe kardashian': 1,
#          'kardashian influencer': 1,
#          'influencer new': 1,
#          'new migraine': 1,
#          'migraine drug': 1,
#          'round like': 11,
#          'like beyond': 1,
#          'beyond meat': 11,
#          'cramer desperately': 1,
#          'desperately need': 1,
#          'need another': 1,
#          'another round': 1,
#          'round federal': 1,
#          'federal stimulus': 1,
#          'stimulus despite': 1,
#          'despite vaccine': 1,
#          'vaccine progress': 2,
#          'round buy': 31,
#          'buy vmware': 1,
#          'street something': 1,
#          'something highly': 1,
#          'highly unusual': 1,
#          'unusual tuesdays': 1,
#          'tuesdays session': 2,
#          'session jim': 1,
#          'charts suggest': 18,
#          'suggest sp': 2,
#          'sp 500': 65,
#          '500 climb': 1,
#          'climb stall': 1,
#          'stall end': 1,
#          'end july': 1,
#          'july jim': 1,
#          'cramer warns': 18,
#          'salesforces marc': 4,
#          'marc benioff': 12,
#          'benioff face': 1,
#          'face masks': 1,
#          'masks end': 1,
#          'end us': 1,
#          'us coronavirus': 1,
#          'coronavirus crisis': 3,
#          'crisis within': 1,
#          'within weeks': 1,
#          'crown castles': 1,
#          'castles good': 1,
#          'good story': 1,
#          'story get': 1,
#          'get even': 2,
#          'even better': 3,
#          'better activist': 1,
#          'activist fight': 1,
#          'fight jim': 1,
#          'ellevests sallie': 1,
#          'sallie krawcheck': 2,
#          'krawcheck says': 1,
#          'says economic': 1,
#          'economic crisis': 1,
#          'crisis caused': 1,
#          'caused shecession': 1,
#          'round zooms': 1,
#          'zooms pullback': 1,
#          'pullback buying': 1,
#          'buying opportunity': 8,
#          'cramers earnings': 1,
#          'earnings watch': 1,
#          'watch banks': 2,
#          'banks get': 1,
#          'get hammered': 1,
#          'hammered things': 1,
#          'things could': 2,
#          'could get': 9,
#          'get ugly': 2,
#          'stay invested': 2,
#          'invested us': 1,
#          'us markets': 4,
#          'markets next': 1,
#          'next two': 2,
#          'two years': 2,
#          'years strategist': 1,
#          'dbs sees': 1,
#          'sees signs': 3,
#          'signs healthy': 1,
#          'healthy us': 1,
#          'us market': 1,
#          'market rally': 8,
#          'aggressive policy': 1,
#          'policy bolstering': 1,
#          'bolstering markets': 1,
#          'markets hirtle': 1,
#          'hirtle callaghan': 1,
#          'big business': 1,
#          'business bouncing': 1,
#          'bouncing back': 2,
#          'back bouncing': 1,
#          'back vengeance': 1,
#          'round dont': 29,
#          'dont like': 6,
#          'like archerdanielsmidland': 1,
#          'archerdanielsmidland co': 1,
#          'sustainable produce': 1,
#          'produce supplier': 1,
#          'supplier apeel': 1,
#          'apeel lands': 1,
#          'lands deal': 1,
#          'deal wakefern': 1,
#          'wakefern grocery': 1,
#          'grocery stores': 2,
#          'cramer deciphers': 2,
#          'deciphers speculative': 1,
#          'speculative bluechip': 1,
#          'bluechip stocks': 1,
#          'stocks driving': 1,
#          'driving market': 1,
#          'round blackrock': 1,
#          'blackrock buy': 1,
#          '500 could': 6,
#          'ugly near': 1,
#          'near future': 1,
#          'future jim': 2,
#          'conagra ceo': 2,
#          'ceo revamping': 1,
#          'revamping mrs': 1,
#          'mrs butterworths': 1,
#          'butterworths brand': 1,
#          'brand perception': 1,
#          'perception reality': 1,
#          'round nokia': 3,
#          'nokia good': 1,
#          'good things': 1,
#          'things coming': 1,
#          'cramer breaks': 17,
#          'breaks favorite': 1,
#          'favorite stocks': 3,
#          'stocks record': 1,
#          'record second': 1,
#          'second quarter': 2,
#          'cramer saw': 1,
#          'saw lot': 1,
#          'lot encouraging': 1,
#          'encouraging signs': 1,
#          'signs mondays': 1,
#          'mondays session': 1,
#          'round james': 1,
#          'james taiclet': 1,
#          'taiclet make': 1,
#          'make lockheed': 1,
#          'lockheed martin': 6,
#          'martin money': 1,
#          'restaurant brands': 1,
#          'brands ceo': 6,
#          'ceo popeyes': 1,
#          'popeyes chicken': 1,
#          'chicken sandwich': 1,
#          'sandwich unprecedented': 1,
#          'unprecedented impact': 1,
#          'impact business': 1,
#          'cramer adds': 2,
#          'adds new': 1,
#          'new stocks': 1,
#          'stocks recommends': 1,
#          'recommends buying': 3,
#          'buying 12': 1,
#          '12 laggards': 1,
#          'laggards covid19': 1,
#          'covid19 index': 3,
#          'benioff says': 3,
#          'says 35': 1,
#          '35 states': 1,
#          'states using': 1,
#          'using salesforces': 1,
#          'salesforces contact': 1,
#          'contact tracing': 2,
#          'tracing technology': 1,
#          'technology coronavirus': 1,
#          'round stay': 3,
#          'stay yeti': 1,
#          'stayathome stocks': 1,
#          'stocks surged': 1,
#          'surged texas': 1,
#          'texas paused': 1,
#          'paused reopening': 1,
#          'reopening jim': 2,
#          'awaken america': 1,
#          'america trade': 1,
#          'trade taken': 1,
#          'taken turn': 1,
#          'turn worse': 1,
#          'worse jim': 1,
#          'buy ulta': 1,
#          'ulta beauty': 3,
#          'rhode island': 2,
#          'island governor': 2,
#          'governor mulls': 1,
#          'mulls restrictions': 1,
#          'restrictions travelers': 1,
#          'travelers coronavirus': 1,
#          'coronavirus hotspot': 1,
#          'hotspot states': 1,
#          'albertsons stock': 1,
#          'stock worth': 5,
#          'worth buying': 14,
#          'buying 25': 1,
#          '25 ipos': 1,
#          'ipos jim': 1,
#          'us recovery': 1,
#          'recovery might': 1,
#          'might vshaped': 1,
#          'vshaped like': 1,
#          'like squareroot': 1,
#          'squareroot sign': 1,
#          'sign blackstone': 1,
#          'expect ushaped': 1,
#          'ushaped economic': 1,
#          'economic recovery': 1,
#          'recovery strategist': 2,
#          'says playing': 1,
#          'playing larry': 1,
#          'larry williams': 2,
#          'williams fourth': 1,
#          'fourth july': 1,
#          'july trade': 1,
#          'trade makes': 1,
#          'makes lot': 1,
#          'lot sense': 1,
#          'round two': 2,
#          'two thumbs': 1,
#          'thumbs astrazeneca': 1,
#          'impossible foods': 2,
#          'foods ceo': 1,
#          'says meat': 1,
#          'meat industry': 1,
#          'industry obsolete': 1,
#          'obsolete 15': 1,
#          '15 years': 1,
#          'years thats': 1,
#          'thats mission': 1,
#          'spotifys story': 1,
#          'story starting': 1,
#          'starting mirror': 1,
#          'mirror netflixs': 1,
#          'netflixs jim': 1,
#          'recession recovery': 1,
#          'recovery stocks': 1,
#          'stocks working': 4,
#          'working trend': 1,
#          'trend sustainable': 1,
#          'sustainable jim': 1,
#          'barstools dave': 1,
#          'dave portnoy': 1,
#          'portnoy says': 1,
#          'says hell': 1,
#          'hell focus': 1,
#          'focus sports': 1,
#          'sports betting': 1,
#          'betting sports': 1,
#          'sports return': 1,
#          'round caterpillar': 1,
#          'caterpillar needs': 1,
#          'needs acceleration': 1,
#          'acceleration economy': 1,
#          'nielsen ceo': 1,
#          'ceo explains': 11,
#          'explains took': 1,
#          'took additional': 1,
#          'additional role': 1,
#          'role chief': 1,
#          'chief diversity': 1,
#          'diversity officer': 1,
#          'suggest new': 1,
#          'new highs': 13,
#          'highs could': 1,
#          'could table': 1,
#          'table sp': 1,
#          '500 jim': 1,
#          'round patient': 1,
#          'patient person': 1,
#          'person wait': 1,
#          'wait ge': 1,
#          'ge payoff': 1,
#          'cramer 10': 3,
#          '10 bull': 1,
#          'bull markets': 2,
#          'markets wall': 1,
#          'street stocks': 1,
#          'stocks leading': 2,
#          'leading way': 1,
#          'round stmicroelectronics': 1,
#          'stmicroelectronics good': 1,
#          'good company': 2,
#          'union pacific': 3,
#          'pacific ceo': 2,
#          'ceo sees': 7,
#          'signs optimism': 1,
#          'optimism multiple': 1,
#          'multiple markets': 1,
#          'markets economy': 1,
#          'economy recovers': 1,
#          'royal pharma': 1,
#          'pharma came': 1,
#          'came public': 1,
#          'public golden': 1,
#          'golden age': 2,
#          'age medical': 1,
#          'medical research': 1,
#          'research jim': 1,
#          'cramer advises': 6,
#          'advises investors': 3,
#          'investors continue': 1,
#          'continue investing': 1,
#          'investing based': 2,
#          'based new': 1,
#          'new normal': 4,
#          'cramer channels': 2,
#          'channels wall': 1,
#          'street legend': 1,
#          'legend martin': 1,
#          'martin zweig': 1,
#          'zweig dont': 1,
#          'dont fight': 2,
#          'fight tape': 1,
#          'tape dont': 1,
#          'fight fed': 1,
#          'cramer reacts': 2,
#          'reacts trump': 1,
#          'trump administrations': 1,
#          'administrations potential': 1,
#          'potential 1': 1,
#          '1 trillion': 7,
#          'trillion infrastructure': 1,
#          'infrastructure proposal': 1,
#          'round lets': 1,
#          'lets buy': 1,
#          'buy pinterest': 1,
#          'canopy growth': 9,
#          'growth ceo': 4,
#          'ceo expects': 2,
#          'expects weed': 1,
#          'weed legalized': 1,
#          'legalized federally': 1,
#          'federally 2022': 1,
#          'campbell soup': 2,
#          'soup ceo': 1,
#          'says june': 1,
#          'june pantry': 1,
#          'pantry sales': 1,
#          'sales unusually': 1,
#          'unusually high': 1,
#          'high despite': 1,
#          'despite reopening': 1,
#          'reopening economy': 1,
#          'round virgin': 2,
#          'virgin galactic': 3,
#          'galactic dangerous': 1,
#          'dangerous game': 1,
#          'cramer investors': 18,
#          'investors concerned': 1,
#          'concerned spiking': 1,
#          'spiking coronavirus': 1,
#          'coronavirus cases': 1,
#          'cases buy': 1,
#          'buy stocks': 14,
#          'cramer recommends': 3,
#          'buying 17': 1,
#          '17 cloud': 1,
#          'cloud stocks': 6,
#          'stocks based': 1,
#          'based rule': 1,
#          'rule 40': 1,
#          'ahead overbought': 1,
#          'overbought market': 1,
#          'market history': 1,
#          'centene ceo': 4,
#          'ceo calls': 4,
#          'calls better': 1,
#          'better education': 1,
#          'education atrisk': 1,
#          'atrisk youth': 1,
#          'youth one': 1,
#          'one solution': 1,
#          'solution racial': 1,
#          'racial disparities': 1,
#          'round alibaba': 1,
#          'alibaba chinese': 1,
#          'chinese stock': 1,
#          'stock recommend': 1,
#          'pullback nasdaq': 1,
#          'nasdaq good': 1,
#          'good opportunity': 1,
#          'opportunity join': 1,
#          'join uptrend': 1,
#          'uptrend daryl': 1,
#          'daryl guppy': 6,
#          'threats becoming': 1,
#          'becoming higher': 1,
#          'higher l3harris': 1,
#          'l3harris ceo': 1,
#          'tech driving': 1,
#          'driving future': 1,
#          'future warfare': 1,
#          'ceo tommy': 1,
#          'tommy hilfiger': 2,
#          'hilfiger owner': 1,
#          'owner vows': 1,
#          'vows better': 1,
#          'better corporate': 1,
#          'corporate diversity': 1,
#          'diversity social': 1,
#          'social justice': 1,
#          'dont want': 6,
#          'want anything': 1,
#          'anything real': 1,
#          'real estate': 1,
#          'estate development': 1,
#          'development company': 1,
#          'buying stocks': 5,
#          'stocks thursdays': 1,
#          'thursdays brutal': 1,
#          'brutal rout': 1,
#          'round cloudflare': 1,
#          'cloudflare good': 1,
#          'street cant': 2,
#          'cant rally': 1,
#          'rally much': 1,
#          'much higher': 4,
#          'higher without': 1,
#          'without coronavirus': 1,
#          'coronavirus vaccine': 3,
#          'vaccine jim': 1,
#          'polaris onceinageneration': 1,
#          'onceinageneration opportunity': 1,
#          'opportunity jim': 1,
#          'hertzs stock': 1,
#          'stock may': 3,
#          'may look': 1,
#          'look cheap': 1,
#          'cheap cramer': 1,
#          'cramer cautions': 2,
#          'cautions buying': 1,
#          'round general': 3,
#          'general mills': 2,
#          'mills axon': 1,
#          'axon enterprise': 1,
#          'enterprise worth': 1,
#          'worth buy': 1,
#          'cramer urges': 1,
#          'urges investors': 1,
#          'investors wary': 1,
#          'wary airline': 1,
#          'airline cruise': 1,
#          'cruise stocks': 2,
#          'stocks buy': 10,
#          'buy 5': 1,
#          '5 winners': 1,
#          'winners instead': 1,
#          'markets could': 3,
#          'could go': 7,
#          'go even': 1,
#          'even higher': 2,
#          'higher liquiditydriven': 1,
#          'liquiditydriven rally': 1,
#          'rally professor': 1,
#          'expect fed': 2,
#          'fed continue': 1,
#          'continue provide': 1,
#          'provide support': 1,
#          'support propel': 1,
#          'propel economy': 1,
#          'economy strategist': 1,
#          'round software': 1,
#          'software maker': 1,
#          'maker ping': 1,
#          'ping identity': 1,
#          'identity buy': 1,
#          'cramer stocks': 7,
#          'stocks helped': 1,
#          'helped power': 1,
#          'power nasdaq': 1,
#          'nasdaq record': 1,
#          'record high': 2,
#          'high pandemic': 1,
#          'ceo airstream': 1,
#          'airstream maker': 1,
#          'maker says': 2,
#          'says new': 2,
#          'new people': 1,
#          'people seeing': 1,
#          'seeing benefits': 1,
#          'benefits traveling': 1,
#          'traveling rv': 1,
#          'rv pandemic': 1,
#          'global indexes': 1,
#          'indexes surpassed': 1,
#          'surpassed 12month': 1,
#          '12month targets': 1,
#          'targets cio': 1,
#          'future commerce': 1,
#          'commerce needs': 1,
#          'needs diverse': 1,
#          'diverse voices': 1,
#          'voices shopify': 1,
#          'shopify coo': 3,
#          'coo says': 2,
#          'round macys': 1,
#          'macys stock': 1,
#          'stock go': 1,
#          'go higher': 7,
#          'cramer pandemic': 1,
#          'pandemic led': 1,
#          'led one': 1,
#          'one greatest': 2,
#          'greatest wealth': 1,
#          'wealth transfers': 1,
#          'transfers history': 1,
#          'nancy pelosi': 3,
#          'pelosi calls': 1,
#          'calls strong': 1,
#          'strong change': 1,
#          'change response': 1,
#          'response nationwide': 1,
#          'nationwide unrest': 1,
#          'stand behind': 1,
#          'behind 3400': 1,
#          '3400 target': 1,
#          'target sp': 1,
#          '500 q1': 1,
#          'q1 2021': 1,
#          '2021 bmo': 1,
#          'bmo capital': 1,
#          'capital markets': 1,
#          'crowdstrike ceo': 2,
#          'explains future': 1,
#          'future remote': 1,
#          'remote work': 2,
#          'work security': 1,
#          'security look': 1,
#          'round microsoft': 5,
#          'microsoft fits': 1,
#          'fits pattern': 2,
#          'pattern market': 1,
#          'market wants': 1,
#          'investors rotating': 2,
#          'rotating stocks': 1,
#          'china first': 1,
#          'first leading': 1,
#          'leading indicator': 1,
#          'indicator rebound': 1,
#          'rebound autos': 1,
#          'autos marvell': 1,
#          'marvell tech': 2,
#          'tech ceo': 2,
#          'round im': 17,
#          'im starting': 1,
#          'starting warm': 1,
#          'warm wells': 1,
#          'wells fargo': 13,
#          'china europe': 1,
#          'europe bailed': 1,
#          'bailed stock': 1,
#          'stock market': 39,
#          'market jim': 7,
#          'camping rv': 1,
#          'rv stocks': 1,
#          'stocks back': 1,
#          'back big': 1,
#          'big way': 1,
#          'way jim': 1,
#          'chipotle ceo': 3,
#          'ceo stores': 1,
#          'stores damaged': 1,
#          'damaged protests': 1,
#          'protests patch': 1,
#          'patch fix': 1,
#          'cramer wall': 8,
#          'wall streets': 10,
#          'streets relation': 1,
#          'relation george': 1,
#          'george floyd': 1,
#          'floyd protests': 1,
#          'protests market': 1,
#          'market conscience': 1,
#          'round harleydavidson': 1,
#          'harleydavidson buy': 1,
#          'round cognex': 1,
#          'cognex manufactures': 1,
#          'manufactures america': 1,
#          'america celebrated': 1,
#          'salesforce costco': 1,
#          'costco flashing': 1,
#          'flashing buy': 2,
#          'buy signals': 1,
#          'signals investors': 1,
#          'investors jim': 4,
#          'ahead bad': 1,
#          'bad time': 1,
#          'time trade': 1,
#          'trade war': 33,
#          'good time': 5,
#          'time take': 1,
#          'take profits': 3,
#          'profits us': 1,
#          'us stock': 1,
#          'market analyst': 4,
#          'buy amd': 1,
#          'amd intel': 1,
#          'says market': 3,
#          'market still': 2,
#          'still rough': 1,
#          'rough ride': 1,
#          'ride suggests': 1,
#          'suggests sticking': 1,
#          'sticking remote': 1,
#          'remote tech': 1,
#          'tech stocks': 17,
#          'benioff salesforces': 1,
#          'salesforces deal': 1,
#          'deal att': 1,
#          'att one': 1,
#          'one largest': 1,
#          'largest transactions': 1,
#          'transactions weve': 1,
#          'weve ever': 1,
#          'ever done': 1,
#          'hp ceo': 2,
#          'ceo commits': 1,
#          'commits companys': 1,
#          'companys buyback': 1,
#          'buyback program': 1,
#          'program says': 1,
#          'says stock': 3,
#          'stock undervalued': 2,
#          'round waste': 1,
#          'waste management': 4,
#          'management buy': 1,
#          'think theyre': 2,
#          'theyre confused': 1,
#          'confused jim': 1,
#          'says bull': 1,
#          'bull investors': 1,
#          'investors one': 1,
#          'one thing': 2,
#          'thing wrong': 1,
#          'wrong economy': 2,
#          'corteva agriscience': 1,
#          'agriscience expects': 1,
#          'expects midmichigan': 1,
#          'midmichigan floods': 1,
#          'floods minimal': 1,
#          'minimal impact': 1,
#          'impact revenue': 1,
#          'cramer reveals': 16,
#          'reveals stocks': 1,
#          'stocks betting': 1,
#          'betting vshaped': 1,
#          'vshaped recovery': 1,
#          'round canopy': 3,
#          'canopy legit': 1,
#          'legit cannabis': 1,
#          'cannabis stocks': 3,
#          'cramer shakes': 1,
#          'shakes cramer': 1,
#          'cramer covid19': 2,
#          'index wall': 1,
#          'street confident': 1,
#          'confident recovery': 1,
#          'target saw': 1,
#          'saw strength': 1,
#          'strength april': 1,
#          'april across': 1,
#          'across entire': 1,
#          'entire portfolio': 1,
#          'portfolio ceo': 1,
#          'ceo brian': 2,
#          'brian cornell': 1,
#          'cornell says': 1,
#          'shelterinplace lasting': 1,
#          'lasting impact': 1,
#          'impact consumer': 1,
#          'consumer behavior': 1,
#          'behavior jim': 1,
#          'round prefer': 4,
#          'prefer tesla': 1,
#          'tesla ford': 1,
#          'street doesnt': 2,
#          'doesnt like': 1,
#          'like ad': 1,
#          'ad hominem': 1,
#          'hominem jim': 1,
#          'warns renewed': 1,
#          'renewed uschina': 1,
#          'uschina tensions': 1,
#          'round consolidation': 1,
#          'consolidation positive': 1,
#          'positive citrix': 1,
#          'citrix systems': 1,
#          'faang emerges': 1,
#          'emerges latest': 1,
#          'latest group': 1,
#          'group lead': 1,
#          'lead market': 2,
#          'lowes support': 1,
#          'support reopening': 1,
#          'reopening minority': 1,
#          'minority businesses': 1,
#          'businesses 25': 1,
#          '25 million': 1,
#          'million grants': 1,
#          'small midcap': 1,
#          'midcap equities': 1,
#          'equities reflective': 1,
#          'reflective real': 1,
#          'real us': 1,
#          'us economy': 6,
#          'economy wells': 1,
#          'coronavirus powering': 1,
#          'powering rush': 1,
#          'rush webbased': 1,
#          'webbased contact': 1,
#          'contact centers': 1,
#          'centers five9': 1,
#          'five9 ceo': 1,
#          'weve probably': 1,
#          'probably taken': 1,
#          'taken depression': 1,
#          'depression table': 1,
#          'table jim': 1,
#          'round disney': 2,
#          'disney going': 1,
#          'going get': 2,
#          'cramer chart': 2,
#          'chart action': 1,
#          'action suggests': 1,
#          'suggests upside': 1,
#          'upside sp': 2,
#          '500 breaks': 2,
#          'breaks key': 1,
#          'key hurdle': 1,
#          'round penske': 1,
#          'penske automotive': 1,
#          'automotive inexpensive': 1,
#          'inexpensive stock': 1,
#          'investors get': 3,
#          'get optimistic': 1,
#          'optimistic moderna': 1,
#          'moderna vaccine': 1,
#          'heres whats': 1,
#          'whats driving': 2,
#          'driving stocks': 1,
#          'stocks higher': 3,
#          'higher despite': 1,
#          'despite mounting': 1,
#          'mounting economic': 1,
#          'economic worries': 1,
#          'worries kevin': 1,
#          'kevin oleary': 3,
#          'draftkings ceo': 1,
#          'ceo esports': 1,
#          'esports betting': 1,
#          'betting surged': 1,
#          'surged pandemic': 1,
#          'pandemic due': 1,
#          'due pentup': 1,
#          'pentup demand': 1,
#          'demand sports': 1,
#          'round never': 1,
#          'never buy': 3,
#          'buy caterpillar': 1,
#          'caterpillar going': 1,
#          'going recession': 1,
#          'ahead bets': 1,
#          'bets another': 1,
#          'another uschina': 1,
#          'uschina trade': 21,
#          'war sparks': 1,
#          'favor us': 1,
#          'us stocks': 4,
#          'stocks nonus': 1,
#          'nonus stocks': 1,
#          'stocks wells': 1,
#          'new membership': 1,
#          'membership signups': 1,
#          'signups par': 1,
#          'par last': 1,
#          'last year': 2,
#          'year planet': 1,
#          'planet fitness': 3,
#          'fitness ceo': 1,
#          'round callaway': 1,
#          'callaway golf': 1,
#          'golf stock': 1,
#          'stock investors': 1,
#          'get long': 1,
#          'big chains': 1,
#          'chains last': 1,
#          'last survivors': 1,
#          'survivors without': 1,
#          'without stimulus': 1,
#          'stimulus relief': 1,
#          'relief jim': 1,
#          'suggest pain': 1,
#          'pain store': 1,
#          'store market': 1,
#          'market reaches': 1,
#          'reaches buyable': 1,
#          'buyable bottom': 1,
#          'bottom jim': 3,
#          'cisco ceo': 4,
#          'ceo chuck': 1,
#          'chuck robbins': 1,
#          'robbins future': 1,
#          'future postpandemic': 1,
#          'postpandemic workplace': 1,
#          'workplace based': 1,
#          'based hybrid': 1,
#          'hybrid model': 1,
#          'round shopify': 1,
#          'shopify hottest': 1,
#          'hottest stock': 1,
#          'charts show': 30,
#          'show nvidia': 1,
#          'nvidia amd': 1,
#          'amd qualcomm': 1,
#          'qualcomm lot': 1,
#          'lot room': 1,
#          'room run': 12,
#          'run jim': 4,
#          'reveals playbook': 2,
#          'playbook says': 2,
#          'says investors': 5,
#          'investors start': 1,
#          'start slowly': 1,
#          'slowly buying': 1,
#          'stocks thursday': 1,
#          'thursday afternoon': 1,
#          'us running': 1,
#          'running time': 1,
#          'time stave': 1,
#          'stave depression': 1,
#          'depression without': 1,
#          'without reopening': 1,
#          'uber willing': 1,
#          'willing pay': 1,
#          'pay genius': 1,
#          'genius move': 1,
#          'move buy': 1,
#          'buy grubhub': 1,
#          'grubhub jim': 1,
#          'round dow': 1,
#          'dow inc': 2,
#          'inc well': 1,
#          'speaker nancy': 1,
#          'pelosi 3': 1,
#          '3 trillion': 1,
#          'trillion coronavirus': 1,
#          'coronavirus relief': 1,
#          'relief bill': 1,
#          'bill big': 1,
#          'big ticket': 1,
#          'ticket big': 1,
#          'big problem': 2,
#          'oleary youre': 1,
#          'youre worried': 3,
#          'worried dividend': 1,
#          'cuts time': 1,
#          'time use': 1,
#          'use actively': 1,
#          'actively managed': 1,
#          'managed etfs': 1,
#          'coronavirus ushered': 1,
#          'ushered death': 1,
#          'death call': 1,
#          'call center': 1,
#          'center liveperson': 1,
#          'liveperson ceo': 2,
#          'want around': 1,
#          'around company': 1,
#          'company cutting': 1,
#          'cutting dividends': 1,
#          'cramer reviews': 12,
#          'reviews top': 3,
#          'top 10': 1,
#          '10 stocks': 1,
#          'stocks difficult': 1,
#          'difficult moment': 1,
#          'moment cramer': 1,
#          'quality really': 1,
#          'really matters': 1,
#          'matters investors': 1,
#          'investors 2020': 1,
#          '2020 says': 3,
#          'says shark': 1,
#          'shark tanks': 3,
#          'tanks kevin': 1,
#          'dividend payers': 1,
#          'payers still': 1,
#          'still winners': 1,
#          'winners market': 1,
#          'market etf': 1,
#          'etf analyst': 1,
#          'analyst says': 6,
#          'says heres': 1,
#          'financials flashing': 1,
#          'flashing warning': 1,
#          'warning sign': 2,
#          'sign investors': 1,
#          'investors says': 1,
#          'says trader': 2,
#          'norwegian cruise': 4,
#          'cruise line': 3,
#          'line ceo': 2,
#          'ceo expect': 2,
#          'expect sail': 1,
#          'sail sometime': 1,
#          'sometime 2020': 1,
#          'like bank': 1,
#          'bank stocks': 12,
#          'cramer moderna': 1,
#          'moderna vaccinesparked': 1,
#          'vaccinesparked rally': 1,
#          'rally lets': 1,
#          'lets get': 1,
#          'get ahead': 2,
#          'suddenly cyber': 1,
#          'cyber monday': 1,
#          'monday etsy': 1,
#          'etsy ceo': 5,
#          'says sales': 1,
#          'sales spiked': 1,
#          'spiked 79': 1,
#          '79 april': 1,
#          'meat ceo': 1,
#          'ceo looks': 1,
#          'looks win': 1,
#          ...})
